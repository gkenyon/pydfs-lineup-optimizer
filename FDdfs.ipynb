# %%
from operator import imod
from pydfs_lineup_optimizer import get_optimizer, Site, Sport
from pydfs_lineup_optimizer import stacks, TeamStack, PlayersGroup
optimizer = get_optimizer(Site.FANDUEL, Sport.BASEBALL)

optimizer.load_players_from_csv("D:\Downloads\FanDuel-MLB-2022 ET-07 ET-04 ET-77893-players-list.csv")
optimizer.add_stack(TeamStack(3, for_teams=['ATL', 'NYM'], max_exposure=.1))
for lineup in optimizer.optimize(n=10):
    print(lineup)
    print(lineup.players)  # list of players
    print(lineup.fantasy_points_projection)
    print(lineup.salary_costs)
optimizer.export('D:\Downloads\FDresult.csv')
# Out:
# <>:6: DeprecationWarning: invalid escape sequence \D
# <>:13: DeprecationWarning: invalid escape sequence \D
# <>:6: DeprecationWarning: invalid escape sequence \D
# <>:13: DeprecationWarning: invalid escape sequence \D
# C:\Users\gkeny\AppData\Local\Temp\ipykernel_49104\1831043466.py:6: DeprecationWarning: invalid escape sequence \D
#   optimizer.load_players_from_csv("D:\Downloads\FanDuel-MLB-2022 ET-07 ET-04 ET-77893-players-list.csv")
# C:\Users\gkeny\AppData\Local\Temp\ipykernel_49104\1831043466.py:13: DeprecationWarning: invalid escape sequence \D
#   optimizer.export('D:\Downloads\FDresult.csv')
# c:\Users\gkeny\.vscode\pydfs-lineup-optimizer\pydfs_lineup_optimizer\utils.py:156: DeprecationWarning: available_teams will be removed in version 3.7, use player_pool.available_teams instead
#   warnings.warn(text, DeprecationWarning)
# ...
